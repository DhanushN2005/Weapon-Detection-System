# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanushN2005/Weapon-Detection-System/blob/main/Weapon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17521, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 17521 (delta 9), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17521/17521), 16.61 MiB | 24.75 MiB/s, done.
# Resolving deltas: 100% (11998/11998), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.1 MB/s eta 0:00:00
# ...

# %%
import yaml

data_yaml = {
    'train': '/content/drive/MyDrive/DL_data/dataset/images/train',
    'val': '/content/drive/MyDrive/DL_data/dataset/images/val',
    'nc': 2,
    'names': ['Knife', 'Handgun']
}

with open('weapon.yaml', 'w') as f:
    yaml.dump(data_yaml, f)

print("✅ weapon.yaml created.")

import yaml

custom_hyp = {
    'lr0': 0.01,            # initial learning rate
    'lrf': 0.1,             # final learning rate (multiplier)
    'momentum': 0.937,
    'weight_decay': 0.0005,
    'warmup_epochs': 3.0,
    'warmup_momentum': 0.8,
    'warmup_bias_lr': 0.1,
    'box': 0.05,            # box loss gain
    'cls': 0.5,             # cls loss gain
    'cls_pw': 1.0,
    'obj': 1.0,             # obj loss gain (scale with pixels)
    'obj_pw': 1.0,
    'iou_t': 0.20,          # IoU training threshold
    'anchor_t': 4.0,        # anchor-multiple threshold
    'fl_gamma': 0.0,        # focal loss gamma
    'hsv_h': 0.015,
    'hsv_s': 0.7,
    'hsv_v': 0.4,
    'degrees': 0.0,
    'translate': 0.1,
    'scale': 0.5,
    'shear': 0.0,
    'perspective': 0.0,
    'flipud': 0.0,
    'fliplr': 0.5,
    'mosaic': 1.0,
    'mixup': 0.0,
    'copy_paste': 0.0
}

with open('custom_hyp.yaml', 'w') as f:
    yaml.dump(custom_hyp, f)

print("✅ Updated full custom_hyp.yaml created.")
# Out:
# ✅ weapon.yaml created.
# ✅ Updated full custom_hyp.yaml created.

# %%
import os
import subprocess
import torch

# Paths to check
data_file = 'weapon.yaml'
hyp_file = 'custom_hyp.yaml'

# Sanity checks
assert os.path.exists(data_file), f"❌ Data config file not found: {data_file}"
assert os.path.exists(hyp_file), f"❌ Hyp config file not found: {hyp_file}"

# Optional: Check for GPU
if not torch.cuda.is_available():
    print("⚠️ Warning: CUDA is not available. Training will run on CPU, which may be slow.")

# Safe batch size for low-resource environments
batch_size = '16'  # reduce if still getting OOM

# Construct the command
command = [
    'python', 'train.py',
    '--img', '416',
    '--batch', batch_size,
    '--epochs', '5',
    '--data', data_file,
    '--weights', 'yolov5s.pt',
    '--project', 'runs/train',
    '--name', 'weapon_evolve',
    '--exist-ok',
    '--cache',
    '--hyp', hyp_file
]

# Run the command
print(f"🚀 Starting YOLOv5 training with batch size {batch_size}...")
result = subprocess.run(command)

# Check result
if result.returncode != 0:
    print(f"❌ Training failed. Return code: {result.returncode}")
else:
    print("✅ Training completed successfully.")
# Out:
# ⚠️ Warning: CUDA is not available. Training will run on CPU, which may be slow.
# 🚀 Starting YOLOv5 training...
# CompletedProcess(args=['python', 'train.py', '--img', '416', '--batch', '64', '--epochs', '5', '--data', 'weapon.yaml', '--weights', 'yolov5s.pt', '--project', 'runs/train', '--name', 'weapon_evolve', '--exist-ok', '--cache', '--hyp', 'custom_hyp.yaml'], returncode=-9)

# %%
# @title Default title text
# !python train.py \
  --img 640 \
  --batch 16 \
  --epochs 50 \
  --data weapon.yaml \
  --weights yolov5s.pt \
  --project runs/train \
  --name weapon_evolve_resume \
  --cache \
  --hyp custom_hyp.yaml
# Out:
# Streaming output truncated to the last 5000 lines.
#       30/49      4.54G      0.033    0.01359   0.001272         33        640:  14% 36/250 [00:09<01:11,  3.01it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       30/49      4.54G     0.0328    0.01357   0.001248         43        640:  15% 37/250 [00:09<01:09,  3.07it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       30/49      4.54G    0.03299    0.01349   0.001224         32        640:  15% 38/250 [00:10<01:08,  3.11it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !cp runs/train/weapon_detector_light/weights/best.pt /content/drive/MyDrive/yolov5_best_weapon.pt
print("✅ Best model saved to Drive.")

# %%
# @title Default title text
pip install opencv-python torch torchvision torchaudio

# %%
# @title Default title text
pip install playsound==1.2.2

# %%
# @title Default title text
from IPython.display import display, Javascript
from google.colab.output import eval_js
import cv2
import numpy as np
from base64 import b64decode
from matplotlib import pyplot as plt

def capture_image():
    js = Javascript('''
        async function capture(){
            const div = document.createElement('div');
            const video = document.createElement('video');
            const canvas = document.createElement('canvas');
            const context = canvas.getContext('2d');
            div.appendChild(video);
            document.body.appendChild(div);

            const stream = await navigator.mediaDevices.getUserMedia({video:true});
            video.srcObject = stream;
            await video.play();

            // Resize canvas to video size
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;

            // Draw current frame on canvas
            context.drawImage(video, 0, 0, canvas.width, canvas.height);

            // Stop video stream
            stream.getVideoTracks()[0].stop();

            // Remove video element
            div.remove();

            return canvas.toDataURL('image/jpeg', 0.8);
        }
        capture();
    ''')
    data = eval_js(js)
    return data

# Capture image
data_url = capture_image()

# Decode the base64 image
header, encoded = data_url.split(",", 1)
img_bytes = b64decode(encoded)

# Convert to numpy array and decode to OpenCV format
img_arr = np.frombuffer(img_bytes, dtype=np.uint8)
img = cv2.imdecode(img_arr, cv2.IMREAD_COLOR)

# Show with matplotlib
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5_best_weapon.pt --img 416 --conf 0.25 --source frame.jpg

# %%
# !cp /content/yolov5/runs/train/weapon_detector_light/weights/ best_weapon.pt
files.download('best_weapon.pt')

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load a YOLOv8 model (e.g., YOLOv8n - Nano)
model = YOLO('yolov8n.yaml')  # or yolov8s.yaml, yolov8m.yaml, etc.

# Train the model
model.train(data='/content/yolov5/weapon.yaml',
            epochs=2,
            imgsz=640,
            batch=16)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...
